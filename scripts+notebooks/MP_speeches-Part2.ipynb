# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc" style="margin-top: 1em;"><ul class="toc-item"><li><span><a href="#Part-2:-Download-all-speeches-belonging-to-MPs-in-list" data-toc-modified-id="Part-2:-Download-all-speeches-belonging-to-MPs-in-list-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Part 2: Download all speeches belonging to MPs in list</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Use-TheyWorkForYou's-API-to-download-all-the-speeches-of-a-particular-MP" data-toc-modified-id="Use-TheyWorkForYou's-API-to-download-all-the-speeches-of-a-particular-MP-1.0.1"><span class="toc-item-num">1.0.1&nbsp;&nbsp;</span>Use TheyWorkForYou's API to download all the speeches of a particular MP</a></span></li><li><span><a href="#Run-the-above-function-in-parallel-for-all-MPs-in-the-list-that-do-not-have-a-speeches-file-yet" data-toc-modified-id="Run-the-above-function-in-parallel-for-all-MPs-in-the-list-that-do-not-have-a-speeches-file-yet-1.0.2"><span class="toc-item-num">1.0.2&nbsp;&nbsp;</span>Run the above function in parallel for all MPs in the list that do not have a speeches file yet</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Analyse all house of commons speeches since 1970

# %% [markdown]
# [Part 1: Get a list of MPs and their affiliations](MP_speeches-Part1.ipynb)
#
# ## Part 2: Download all speeches belonging to MPs in list
#
# [Part 3: Train bigram and trigram models and use them on all speeches](MP_speeches-Part3.ipynb)
#
# [Part 4: Train an LDA topic model and process all speeches with it](MP_speeches-Part4.ipynb)
#
# [Part 5: Analyse the results of the LDA model](MP_speeches-Part5.ipynb)

# %%
import pandas as pd

# %%
# Load the list of MPs from Part 1
mps = pd.read_hdf("list_of_mps.h5", "mps")

# %% [markdown]
# #### Use TheyWorkForYou's API to download all the speeches of a particular MP

# %%
mps
# Out:
#                  First name     Last name                    Party  \
# Person ID
# 10001                 Diane        Abbott                   Labour
# 10002                 Gerry         Adams                Sinn Féin
# 10003                 Irene         Adams                   Labour
# 10004                  Nick        Ainger                   Labour
# 10005                   Bob     Ainsworth                   Labour
# 10006                 Peter     Ainsworth             Conservative
# 10007               Richard         Allan         Liberal Democrat
# 10008                Graham         Allen                   Labour
# 10009                 David         Amess             Conservative
# 10010               Michael        Ancram             Conservative
# 10011                Donald      Anderson                   Labour
# 10012                 Janet      Anderson                   Labour
# 10013                 James     Arbuthnot             Conservative
# 10014                Hilary     Armstrong                   Labour
# 10015                 Paddy       Ashdown         Liberal Democrat
# 10016                   Joe        Ashton                   Labour
# 10017                 Candy      Atherton                   Labour
# 10018             Charlotte        Atkins                   Labour
# 10019                 David      Atkinson             Conservative
# 10020                 Peter      Atkinson             Conservative
# 10021                  John        Austin                   Labour
# 10022                Norman         Baker         Liberal Democrat
# 10023                  Tony        Baldry             Conservative
# 10024                Jackie       Ballard         Liberal Democrat
# 10025                  Tony         Banks                   Labour
# 10026                 Harry        Barnes                   Labour
# 10027                 Kevin        Barron                   Labour
# 10028                  John        Battle                   Labour
# 10029                  Hugh        Bayley                   Labour
# 10030                 Nigel         Beard                   Labour
# ...                     ...           ...                      ...
# 25672                 Laura         Smith                   Labour
# 25673                 Sarah         Jones                   Labour
# 25674               Alister          Jack             Conservative
# 25675             Christine       Jardine         Liberal Democrat
# 25695      https://www.theyworkforyou.com/mp/25695/tanman...
# 25696      https://www.theyworkforyou.com/mp/25696/stephe...
# 25698      https://www.theyworkforyou.com/mp/25698/jack_b...
# 25699      https://www.theyworkforyou.com/mp/25699/eddie_...
# 25700      https://www.theyworkforyou.com/mp/25700/faisal...
# 25701      https://www.theyworkforyou.com/mp/25701/matt_w...
# 25702      https://www.theyworkforyou.com/mp/25702/mike_a...
# 25703      https://www.theyworkforyou.com/mp/25703/andrew...
# 25706      https://www.theyworkforyou.com/mp/25706/emma_d...
#
#                         full_name            clean_name  is_female  \
# Person ID
# 10001                Diane Abbott           dianeabbott       True
# 10002                 Gerry Adams            gerryadams      False
# 10003                 Irene Adams            ireneadams       True
# 10004                 Nick Ainger            nickainger      False
# 10005               Bob Ainsworth          bobainsworth      False
# 10006             Peter Ainsworth        peterainsworth      False
# 10007               Richard Allan          richardallan      False
# 10008                Graham Allen           grahamallen      False
# 10009                 David Amess            davidamess      False
# 10010              Michael Ancram         michaelancram      False
# 10011             Donald Anderson        donaldanderson      False
# 10012              Janet Anderson         janetanderson       True
# 10013             James Arbuthnot        jamesarbuthnot      False
# 10014            Hilary Armstrong       hilaryarmstrong       True
# 10015               Paddy Ashdown          paddyashdown      False
# 10016                  Joe Ashton             joeashton      False
# 10017              Candy Atherton         candyatherton       True
# 10018            Charlotte Atkins       charlotteatkins       True
# 10019              David Atkinson         davidatkinson      False
# 10020              Peter Atkinson         peteratkinson      False
# 10021                 John Austin            johnaustin      False
# 10022                Norman Baker           normanbaker      False
# 10023                 Tony Baldry            tonybaldry      False
# 10024              Jackie Ballard         jackieballard       True
# 10025                  Tony Banks             tonybanks      False
# 10026                Harry Barnes           harrybarnes      False
# 10027                Kevin Barron           kevinbarron      False
# 10028                 John Battle            johnbattle      False
# 10029                 Hugh Bayley            hughbayley      False
# 10030                 Nigel Beard            nigelbeard      False
# ...                           ...                   ...        ...
# 25672                 Laura Smith            laurasmith      False
# 25673                 Sarah Jones            sarahjones      False
# 25674                Alister Jack           alisterjack      False
# 25675           Christine Jardine      christinejardine      False
# 25676         Bambos Charalambous    bamboscharalambous      False
# 25677                David Linden           davidlinden      False
# 25678                 Colin Clark            colinclark      False
# 25679                Neil O'Brien            neilobrien      False
# 25680                  Alex Sobel             alexsobel      False
# 25681                Ellie Reeves           elliereeves      False
# 25682                   Karen Lee              karenlee      False
# 25683                 Ben Bradley            benbradley      False
# 25684             Danielle Rowley        daniellerowley      False
# 25685                  Lee Rowley             leerowley      False
# 25686                Andrew Lewer           andrewlewer      False
# 25687                 Alex Norris            alexnorris      False
# 25689                 Layla Moran            laylamoran      False
# 25690                Luke Pollard           lukepollard      False
# 25691                  Matt Rodda             mattrodda      False
# 25692              Rachel Maclean         rachelmaclean      False
# 25693               Kemi Badenoch          kemibadenoch      False
# 25695      Tanmanjeet Singh Dhesi  tanmanjeetsinghdhesi      False
# 25696                Stephen Kerr           stephenkerr      False
# 25698               Jack Brereton          jackbrereton      False
# 25699                Eddie Hughes           eddiehughes      False
# 10027                                    Kevin Barron_1946
# 10028                                     John Battle_1951
# 10029                                     Hugh Bayley_1952
# 10030                                     Nigel Beard_1938
# ...                                                    ...
# 25672                                                 None
# 25673                                                 None
# 25674                                                 None
# 25675                                                 None
# 25676                             Bambos Charalambous_1967
# 25677                                                 None
# 25678                                     Colin Clark_1968
# 25679                                                 None
# 25680                                                 None
# 25681                                                 None
# 25682                                                 None
# 25683                                                 None
# 25684                                                 None
# 25685                                                 None
# 25686                                                 None
# 25687                                                 None
# 25689                                                 None
# 25690                                    Luke Pollard_1980
# 25691                                                 None
# 25692                                                 None
# 25693                                   Kemi Badenoch_1980
# 25695                          Tanmanjeet Singh Dhesi_1978
# 25696                                                 None
# 25698                                                 None
# 25699                                                 None
# 25700                                                 None
# 25701                                                 None
# 25702                                                 None
# 25703                                                 None
# 25706                                  Emma Dent Coad_1954
#
#                                      mp_wikidata_id    party_wikidata
# Person ID
# 10001        http://www.wikidata.org/entity/Q153454            Labour
# 10002         http://www.wikidata.org/entity/Q76139         Sinn Féin
# 10003        http://www.wikidata.org/entity/Q334498            Labour
# 10004        http://www.wikidata.org/entity/Q325367            Labour
# 10005        http://www.wikidata.org/entity/Q258738            Labour
# 10006        http://www.wikidata.org/entity/Q337709      Conservative
# 10007        http://www.wikidata.org/entity/Q334455  Liberal Democrat
# 10008        http://www.wikidata.org/entity/Q259601            Labour
# 10009        http://www.wikidata.org/entity/Q259646      Conservative
# 10010        http://www.wikidata.org/entity/Q332962      Conservative
# 10011        http://www.wikidata.org/entity/Q334411            Labour
# 10012       http://www.wikidata.org/entity/Q4935679            Labour
# 10013        http://www.wikidata.org/entity/Q259736      Conservative
# 10014        http://www.wikidata.org/entity/Q332660            Labour
# 10015        http://www.wikidata.org/entity/Q333066  Liberal Democrat
# 10016       http://www.wikidata.org/entity/Q6208398            Labour
# 10017        http://www.wikidata.org/entity/Q337833            Labour
# 10018       http://www.wikidata.org/entity/Q4936901            Labour
# 10019        http://www.wikidata.org/entity/Q338243      Conservative
# 10020        http://www.wikidata.org/entity/Q337992      Conservative
# 10021        http://www.wikidata.org/entity/Q338388            Labour
# 10022        http://www.wikidata.org/entity/Q260082  Liberal Democrat
# 10023        http://www.wikidata.org/entity/Q260324      Conservative
# 10024       http://www.wikidata.org/entity/Q6116208  Liberal Democrat
# 10025        http://www.wikidata.org/entity/Q333584            Labour
# 10026       http://www.wikidata.org/entity/Q5566061            Labour
# 10027        http://www.wikidata.org/entity/Q260631            Labour
# 10028        http://www.wikidata.org/entity/Q337561            Labour
# 10029        http://www.wikidata.org/entity/Q260748            Labour
# 10030       http://www.wikidata.org/entity/Q5567795            Labour
# ...                                             ...               ...
# 25672                                          None              None
# 25673                                          None              None
# 25674                                          None              None
# 25675                                          None              None
# 25676      http://www.wikidata.org/entity/Q30165325            Labour
# 25677                                          None              None
# 25678      http://www.wikidata.org/entity/Q30174601      Conservative
# 25679                                          None              None
# 25680                                          None              None
# 25681                                          None              None
# 25682                                          None              None
# 25683                                          None              None
# 25684                                          None              None
# 25685                                          None              None
# 25686                                          None              None
# 25687                                          None              None
# 25689                                          None              None
# 25690      http://www.wikidata.org/entity/Q30164902            Labour
# 25691                                          None              None
# 25692                                          None              None
# 25693      http://www.wikidata.org/entity/Q21592171      Conservative
# 25695      http://www.wikidata.org/entity/Q30169287            Labour
# 25696                                          None              None
# 25698                                          None              None
# 25699                                          None              None
# 25700                                          None              None
# 25701                                          None              None
# 25702                                          None              None
# 25703                                          None              None
# 25706      http://www.wikidata.org/entity/Q30172941            Labour
#
# [2421 rows x 13 columns]

# %%
def get_mp_speeches(mp_id):
    """Get all speeches of a particular MP from the TheyWorkForYou API as save them to a csv file under speeches/"""
    
    # Store TheyWorkForYou API key in separate config file
    from config import TWFY_API_KEY
    import requests
    import pandas as pd
    from bs4 import BeautifulSoup
    
    """Get speeches of a particular MP based on TheyWorkForYou id and convert data into long format pandas data frame.
    Each row represents one speech at a particular date and time"""
    all_speeches = pd.DataFrame()
    rows = [1]
    page_no=1
    
    
    # Get date of latest downloaded speech
    try:
        latest_date = pd.read_csv("speeches/mp-{0}.csv".format(mp_id))\
            .assign(date = lambda df: pd.to_datetime(df.date))\
            .sort_values("date", ascending=False).iloc[0].date
        update_speeches = True
        print("Downloading speeches made after {0}".format(latest_date))
    except FileNotFoundError:
        # If we're running this function for the first time, we want to 
        latest_date = pd.to_datetime("1945-01-01")
        update_speeches = False
    
    not_latest_date = True
    while (len(rows) > 0) or not_latest_date:
        t = requests.get("https://www.theyworkforyou.com/api/getDebates?key={api_key}&\
                     type=commons&person={person}&results_per_page=1000&num={num}&page={page}&output=js&order=d".format(api_key=TWFY_API_KEY,
                                                                                                               person=mp_id,
                                                                                                               num=1000,
                                                                                                               page=page_no))
        rows = t.json()["rows"]
        speeches = []
        # Loop over each row
        for row in rows:
            if pd.to_datetime(row["hdate"], format="%Y-%m-%d") > latest_date:
                speeches.append({
                        'speech_id':row["gid"],
                        'speech_url':row["listurl"],
                        'mp_name':row["speaker"]["name"],
                        'mp_constituency':row["speaker"]["constituency"],
                        'mp_party':row["speaker"]["party"],
                        'mp_id':row["person_id"],
                        'date':pd.to_datetime(row["hdate"], format="%Y-%m-%d"),
                        'time':row["htime"],
                        'section_id':row["section_id"],
                        'subsection_id':row["subsection_id"],
                        'debate_title':row["parent"]["body"],
                        'body':BeautifulSoup(row["body"], "html5lib").get_text()
                    })
            else:
                not_latest_date = False
                break
                    
        speeches = pd.DataFrame(speeches)

        # Concatenate onto complete speeches dataframe
        all_speeches = pd.concat([all_speeches, speeches], ignore_index=True)
        # Increment page_counter
        page_no += 1
        #print(speeches)
    
    print("Got speeches for MP {0}".format(mp_id))
    # Write to new csv file specifically for mp
    all_speeches.to_csv("speeches/mp-{0}{1}.csv".format(mp_id, "_new" if update_speeches else ""), index=False)
    return True
    #return all_speeches

# %% [markdown]
# #### Run the above function in parallel for all MPs in the list that do not have a speeches file yet
# This will take a while (~15 mins, depending on your internet connection)

# %%
# %%time
## Download all MP speeches if this is set to True
## This can take a while
## If speeches have been downloaded previously, it will only download newer speeches and put them in speeches/mp-{id}_new.csv
## You will have to merge them into the main csv yourself!
if False:
    # Figure out which MPs we still need to download
    import glob
    import os
    
    
    downloaded_mps = [int(file.split("/")[-1].split(".")[0].split("-")[1]) for file in glob.glob("./speeches/mp-*.csv")]
    #downloaded_mps = [int(file.split("/")[-1].split(".")[0].split("-")[1].split("_")[0]) for file in glob.glob("./speeches/mp-*_new.csv")]
    
    # If you want to download speeches again, uncomment the next line
    #downloaded_mps = []
    
    mps_to_download = [mp for mp in list(mps.index) if mp not in downloaded_mps]
    # Parallelise downloading of MP speeches
    from multiprocessing import Pool

    # Number of threads to use to fetch
    NUM_THREADS = 16
    # Make list of mp ids
    list_of_mp_ids = mps_to_download
    #list_of_mp_ids = list(mps.query("exists==False")["Person ID"])[:10]

    # Create pool of threads
    pool = Pool(NUM_THREADS)
    # Use pool.map to download speeches mp by mp
    results = pool.map(get_mp_speeches, list_of_mp_ids)
    pool.close()
    pool.join()

    # Remove the empty mp files
    import glob
    import os
    for file in glob.glob("./speeches/mp-*.csv"):
        if os.path.getsize(file) == 1:
            os.remove(file)
# Out:
# Downloading speeches made after 2005-03-23 00:00:00
# Downloading speeches made after 2010-02-24 00:00:00
# Downloading speeches made after 1997-01-29 00:00:00
# Downloading speeches made after 2010-02-04 00:00:00
# Downloading speeches made after 2010-03-04 00:00:00
# Downloading speeches made after 2010-03-09 00:00:00
# Downloading speeches made after 2001-04-02 00:00:00
# Downloading speeches made after 2010-02-22 00:00:00
# Downloading speeches made after 2017-04-25 00:00:00
# Downloading speeches made after 2015-03-03 00:00:00
# Downloading speeches made after 2005-04-05 00:00:00
# Downloading speeches made after 2009-11-23 00:00:00
# Downloading speeches made after 2010-03-29 00:00:00
# Downloading speeches made after 2005-04-05 00:00:00
# Downloading speeches made after 2015-03-26 00:00:00
# Got speeches for MP 10018
# Downloading speeches made after 2005-03-24 00:00:00
# Got speeches for MP 10398
# Downloading speeches made after 2005-03-23 00:00:00
# Got speeches for MP 10390
# Got speeches for MP 10410
# Downloading speeches made after 2005-03-15 00:00:00
# Downloading speeches made after 2010-03-25 00:00:00
# Got speeches for MP 10030
# Downloading speeches made after 2017-09-11 00:00:00
# Got speeches for MP 10406
# Downloading speeches made after 2005-03-14 00:00:00
# Got speeches for MP 10019
# Downloading speeches made after 2009-12-08 00:00:00
# Got speeches for MP 10006
# Downloading speeches made after 2005-04-07 00:00:00
# Got speeches for MP 10014
# Downloading speeches made after 2001-04-25 00:00:00
# Got speeches for MP 10402
# Downloading speeches made after 2005-03-23 00:00:00
# Got speeches for MP 10020
# Downloading speeches made after 2009-12-08 00:00:00
# Got speeches for MP 10403
# Downloading speeches made after 2005-03-24 00:00:00
# Got speeches for MP 10407
# Downloading speeches made after 2001-03-12 00:00:00
# Got speeches for MP 10007
# Downloading speeches made after 2017-02-01 00:00:00
# Got speeches for MP 10021
# Downloading speeches made after 1998-11-10 00:00:00
# Downloading speeches made after 2017-03-29 00:00:00
# Got speeches for MP 25278
# Downloading speeches made after 2017-09-14 00:00:00
# Got speeches for MP 25274
# Downloading speeches made after 2017-09-13 00:00:00
# Got speeches for MP 17973
# Downloading speeches made after 1979-03-19 00:00:00
# Got speeches for MP 25279
# Got speeches for MP 25272
# Downloading speeches made after 2017-09-11 00:00:00
# Got speeches for MP 17946
# Downloading speeches made after 1986-05-20 00:00:00
# Got speeches for MP 25275
# Downloading speeches made after 2017-09-13 00:00:00
# Got speeches for MP 25273
# Downloading speeches made after 2017-07-17 00:00:00
# Got speeches for MP 25276
# Downloading speeches made after 2017-07-19 00:00:00
# Got speeches for MP 25489
# Downloading speeches made after 2017-09-14 00:00:00
# Got speeches for MP 25277
# Downloading speeches made after 2017-09-14 00:00:00
# Got speeches for MP 14187
# Downloading speeches made after 2017-09-13 00:00:00
# Got speeches for MP 25579
# Downloading speeches made after 2017-09-12 00:00:00
# Got speeches for MP 25597
# Downloading speeches made after 2017-09-13 00:00:00
# Got speeches for MP 25490
# Downloading speeches made after 2017-09-12 00:00:00
# Got speeches for MP 25531
# Got speeches for MP 25592
# Downloading speeches made after 2017-09-12 00:00:00
# Got speeches for MP 16389
# Downloading speeches made after 1993-05-05 00:00:00
# Got speeches for MP 25600
# Downloading speeches made after 2017-09-13 00:00:00
# Got speeches for MP 25601
# Got speeches for MP 17975
# Downloading speeches made after 2017-07-12 00:00:00
# Got speeches for MP 25611
# Downloading speeches made after 2017-07-19 00:00:00
# Got speeches for MP 25612
# Downloading speeches made after 2017-06-22 00:00:00
# Got speeches for MP 25614
# Downloading speeches made after 2017-09-14 00:00:00
# Got speeches for MP 25593
# Downloading speeches made after 2017-03-30 00:00:00
# Got speeches for MP 25596
# Downloading speeches made after 2017-09-14 00:00:00
# Got speeches for MP 25616
# Downloading speeches made after 2017-09-07 00:00:00
# Got speeches for MP 25617
# Downloading speeches made after 2017-06-22 00:00:00
# Got speeches for MP 25621
# Downloading speeches made after 2017-09-11 00:00:00
# Got speeches for MP 25618
# Downloading speeches made after 2017-09-11 00:00:00
# Got speeches for MP 25622
# Downloading speeches made after 2017-09-14 00:00:00
# Got speeches for MP 25623
# Downloading speeches made after 2017-09-11 00:00:00
# Got speeches for MP 16390
# Downloading speeches made after 2017-06-22 00:00:00
# Got speeches for MP 25619
# Downloading speeches made after 2017-06-22 00:00:00
# Got speeches for MP 25620
# Downloading speeches made after 2017-09-13 00:00:00
# Got speeches for MP 25637
# Downloading speeches made after 2017-06-22 00:00:00
# Got speeches for MP 25625
# Downloading speeches made after 2017-09-12 00:00:00
# Got speeches for MP 25628
# Downloading speeches made after 2017-07-17 00:00:00
# Got speeches for MP 25638
# Downloading speeches made after 2017-09-12 00:00:00
# Got speeches for MP 25642
# Downloading speeches made after 2017-09-12 00:00:00
# Got speeches for MP 25629
# Downloading speeches made after 2017-09-13 00:00:00
# Got speeches for MP 25630
# Got speeches for MP 25639
# Downloading speeches made after 2017-09-14 00:00:00
# Got speeches for MP 25640
# Downloading speeches made after 2017-09-13 00:00:00
# Got speeches for MP 25646
# Downloading speeches made after 2017-06-22 00:00:00
# Got speeches for MP 25643
# Downloading speeches made after 2017-07-11 00:00:00
# Got speeches for MP 25647
# Downloading speeches made after 2017-09-14 00:00:00
# Got speeches for MP 25644
# Downloading speeches made after 2017-07-13 00:00:00
# Got speeches for MP 25645
# Downloading speeches made after 2017-09-14 00:00:00
# Got speeches for MP 25651
# Downloading speeches made after 2017-07-13 00:00:00
# Got speeches for MP 25652
# Downloading speeches made after 2017-07-19 00:00:00
# Got speeches for MP 25653
# Downloading speeches made after 2017-09-14 00:00:00
# Got speeches for MP 25648
# Downloading speeches made after 2017-09-06 00:00:00
# Got speeches for MP 25654
# Downloading speeches made after 2017-09-14 00:00:00
# Got speeches for MP 25649
# Downloading speeches made after 2017-09-12 00:00:00
# Got speeches for MP 25656
# Downloading speeches made after 2017-06-22 00:00:00
# Got speeches for MP 25660
# Downloading speeches made after 2017-09-12 00:00:00
# Got speeches for MP 17947
# Downloading speeches made after 2017-09-13 00:00:00
# Got speeches for MP 25666
# Downloading speeches made after 2017-09-13 00:00:00
# Got speeches for MP 25657
# Downloading speeches made after 2017-09-13 00:00:00
# Got speeches for MP 25661
# Downloading speeches made after 2017-09-05 00:00:00
# Got speeches for MP 25658
# Downloading speeches made after 2017-09-14 00:00:00
# Got speeches for MP 25662
# Downloading speeches made after 2017-09-06 00:00:00
# Got speeches for MP 25667
# Downloading speeches made after 2017-09-13 00:00:00
# Got speeches for MP 25659
# Downloading speeches made after 2017-07-06 00:00:00
# Got speeches for MP 25664
# Downloading speeches made after 2017-07-19 00:00:00
# Got speeches for MP 25670
# Got speeches for MP 25668
# Downloading speeches made after 2017-09-14 00:00:00
# Downloading speeches made after 2017-09-13 00:00:00
# Got speeches for MP 25674
# Got speeches for MP 25669
# Got speeches for MP 25671
# Downloading speeches made after 2017-07-17 00:00:00
# Got speeches for MP 25672
# Downloading speeches made after 2017-09-07 00:00:00
# Got speeches for MP 25673
# Process ForkPoolWorker-39:
# Process ForkPoolWorker-37:
# Process ForkPoolWorker-34:
# Process ForkPoolWorker-43:
# Process ForkPoolWorker-44:
# Process ForkPoolWorker-33:
# Process ForkPoolWorker-41:
# Traceback (most recent call last):
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-46:
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
# KeyboardInterrupt
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/queues.py", line 343, in get
#     res = self._reader.recv_bytes()
#   File "<ipython-input-41-7790e779c516>", line 32, in get_mp_speeches
#     page=page_no))
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "<ipython-input-41-7790e779c516>", line 32, in get_mp_speeches
#     page=page_no))
#   File "<ipython-input-41-7790e779c516>", line 32, in get_mp_speeches
#     page=page_no))
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/api.py", line 72, in get
#     return request('get', url, params=params, **kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/api.py", line 58, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/api.py", line 72, in get
#     return request('get', url, params=params, **kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/sessions.py", line 508, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/api.py", line 72, in get
#     return request('get', url, params=params, **kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-41-7790e779c516>", line 32, in get_mp_speeches
#     page=page_no))
# KeyboardInterrupt
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/api.py", line 58, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/api.py", line 72, in get
#     return request('get', url, params=params, **kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/api.py", line 58, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/sessions.py", line 508, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/sessions.py", line 508, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/sessions.py", line 618, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/adapters.py", line 440, in send
#     timeout=timeout
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/sessions.py", line 618, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/api.py", line 58, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/sessions.py", line 618, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connectionpool.py", line 601, in urlopen
#     chunked=chunked)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/adapters.py", line 440, in send
#     timeout=timeout
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/sessions.py", line 508, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/adapters.py", line 440, in send
#     timeout=timeout
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connectionpool.py", line 346, in _make_request
#     self._validate_conn(conn)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connectionpool.py", line 601, in urlopen
#     chunked=chunked)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connectionpool.py", line 601, in urlopen
#     chunked=chunked)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connectionpool.py", line 850, in _validate_conn
#     conn.connect()
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/sessions.py", line 618, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connectionpool.py", line 346, in _make_request
#     self._validate_conn(conn)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connectionpool.py", line 346, in _make_request
#     self._validate_conn(conn)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connectionpool.py", line 850, in _validate_conn
#     conn.connect()
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/adapters.py", line 440, in send
#     timeout=timeout
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connection.py", line 326, in connect
#     ssl_context=context)
# Traceback (most recent call last):
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connectionpool.py", line 601, in urlopen
#     chunked=chunked)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connection.py", line 326, in connect
#     ssl_context=context)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/util/ssl_.py", line 329, in ssl_wrap_socket
#     return context.wrap_socket(sock, server_hostname=server_hostname)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connectionpool.py", line 850, in _validate_conn
#     conn.connect()
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/util/ssl_.py", line 329, in ssl_wrap_socket
#     return context.wrap_socket(sock, server_hostname=server_hostname)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connectionpool.py", line 346, in _make_request
#     self._validate_conn(conn)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/ssl.py", line 401, in wrap_socket
#     _context=self, _session=session)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/ssl.py", line 401, in wrap_socket
#     _context=self, _session=session)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/ssl.py", line 808, in __init__
#     self.do_handshake()
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/ssl.py", line 808, in __init__
#     self.do_handshake()
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connectionpool.py", line 850, in _validate_conn
#     conn.connect()
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connection.py", line 326, in connect
#     ssl_context=context)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/ssl.py", line 1061, in do_handshake
#     self._sslobj.do_handshake()
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/util/ssl_.py", line 329, in ssl_wrap_socket
#     return context.wrap_socket(sock, server_hostname=server_hostname)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/ssl.py", line 401, in wrap_socket
#     _context=self, _session=session)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/ssl.py", line 1061, in do_handshake
#     self._sslobj.do_handshake()
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/ssl.py", line 808, in __init__
#     self.do_handshake()
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>()
#
# ~/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     258         in a list that is returned.
#     259         '''
# --> 260         return self._map_async(func, iterable, mapstar, chunksize).get()
#     261
#     262     def starmap(self, func, iterable, chunksize=None):
#
# ~/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/pool.py in get(self, timeout)
#     600
#     601     def get(self, timeout=None):
# --> 602         self.wait(timeout)
#     603         if not self.ready():
#     604             raise TimeoutError
#
# ~/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/pool.py in wait(self, timeout)
#     597
#     598     def wait(self, timeout=None):
# --> 599         self._event.wait(timeout)
#     600
#     601     def get(self, timeout=None):
#
# ~/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# ~/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/ssl.py", line 683, in do_handshake
#     self._sslobj.do_handshake()
# KeyboardInterrupt
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/ssl.py", line 683, in do_handshake
#     self._sslobj.do_handshake()
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connection.py", line 326, in connect
#     ssl_context=context)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/ssl.py", line 1061, in do_handshake
#     self._sslobj.do_handshake()
# KeyboardInterrupt
#   File "<ipython-input-41-7790e779c516>", line 32, in get_mp_speeches
#     page=page_no))
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/ssl.py", line 683, in do_handshake
#     self._sslobj.do_handshake()
# KeyboardInterrupt
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/util/ssl_.py", line 329, in ssl_wrap_socket
#     return context.wrap_socket(sock, server_hostname=server_hostname)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/api.py", line 72, in get
#     return request('get', url, params=params, **kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/ssl.py", line 401, in wrap_socket
#     _context=self, _session=session)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/api.py", line 58, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/ssl.py", line 808, in __init__
#     self.do_handshake()
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/sessions.py", line 508, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/sessions.py", line 618, in send
#     r = adapter.send(request, **kwargs)
# Process ForkPoolWorker-45:
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/adapters.py", line 440, in send
#     timeout=timeout
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/ssl.py", line 1061, in do_handshake
#     self._sslobj.do_handshake()
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connectionpool.py", line 601, in urlopen
#     chunked=chunked)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/ssl.py", line 683, in do_handshake
#     self._sslobj.do_handshake()
# Traceback (most recent call last):
# KeyboardInterrupt
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connectionpool.py", line 346, in _make_request
#     self._validate_conn(conn)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connectionpool.py", line 850, in _validate_conn
#     conn.connect()
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connection.py", line 284, in connect
#     conn = self._new_conn()
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connection.py", line 141, in _new_conn
#     (self.host, self.port), self.timeout, **extra_kw)
#   File "<ipython-input-41-7790e779c516>", line 32, in get_mp_speeches
#     page=page_no))
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/util/connection.py", line 60, in create_connection
#     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/api.py", line 72, in get
#     return request('get', url, params=params, **kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/api.py", line 58, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/sessions.py", line 508, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/socket.py", line 743, in getaddrinfo
#     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
# KeyboardInterrupt
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/sessions.py", line 618, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/adapters.py", line 440, in send
#     timeout=timeout
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connectionpool.py", line 601, in urlopen
#     chunked=chunked)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connectionpool.py", line 346, in _make_request
#     self._validate_conn(conn)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connectionpool.py", line 850, in _validate_conn
#     conn.connect()
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connection.py", line 284, in connect
#     conn = self._new_conn()
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connection.py", line 141, in _new_conn
#     (self.host, self.port), self.timeout, **extra_kw)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/util/connection.py", line 60, in create_connection
#     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/socket.py", line 743, in getaddrinfo
#     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
# KeyboardInterrupt
# Process ForkPoolWorker-48:
# Traceback (most recent call last):
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-41-7790e779c516>", line 32, in get_mp_speeches
#     page=page_no))
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/api.py", line 72, in get
#     return request('get', url, params=params, **kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/api.py", line 58, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/sessions.py", line 508, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/sessions.py", line 618, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/adapters.py", line 440, in send
#     timeout=timeout
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connectionpool.py", line 601, in urlopen
#     chunked=chunked)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connectionpool.py", line 346, in _make_request
#     self._validate_conn(conn)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connectionpool.py", line 850, in _validate_conn
#     conn.connect()
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connection.py", line 284, in connect
#     conn = self._new_conn()
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connection.py", line 141, in _new_conn
#     (self.host, self.port), self.timeout, **extra_kw)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/util/connection.py", line 60, in create_connection
#     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/socket.py", line 743, in getaddrinfo
#     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
# KeyboardInterrupt
# Process ForkPoolWorker-47:
# Traceback (most recent call last):
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-41-7790e779c516>", line 32, in get_mp_speeches
#     page=page_no))
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/api.py", line 72, in get
#     return request('get', url, params=params, **kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/api.py", line 58, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/sessions.py", line 508, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/sessions.py", line 618, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/adapters.py", line 440, in send
#     timeout=timeout
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connectionpool.py", line 601, in urlopen
#     chunked=chunked)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connectionpool.py", line 346, in _make_request
#     self._validate_conn(conn)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connectionpool.py", line 850, in _validate_conn
#     conn.connect()
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connection.py", line 284, in connect
#     conn = self._new_conn()
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connection.py", line 141, in _new_conn
#     (self.host, self.port), self.timeout, **extra_kw)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/util/connection.py", line 60, in create_connection
#     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/socket.py", line 743, in getaddrinfo
#     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
# KeyboardInterrupt
# Process ForkPoolWorker-38:
# Traceback (most recent call last):
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Process ForkPoolWorker-35:
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
# Traceback (most recent call last):
#   File "<ipython-input-41-7790e779c516>", line 32, in get_mp_speeches
#     page=page_no))
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/api.py", line 72, in get
#     return request('get', url, params=params, **kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/api.py", line 58, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/sessions.py", line 508, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/sessions.py", line 618, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/adapters.py", line 440, in send
#     timeout=timeout
#   File "<ipython-input-41-7790e779c516>", line 32, in get_mp_speeches
#     page=page_no))
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connectionpool.py", line 601, in urlopen
#     chunked=chunked)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/api.py", line 72, in get
#     return request('get', url, params=params, **kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connectionpool.py", line 346, in _make_request
#     self._validate_conn(conn)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connectionpool.py", line 850, in _validate_conn
#     conn.connect()
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/api.py", line 58, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connection.py", line 284, in connect
#     conn = self._new_conn()
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/sessions.py", line 508, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connection.py", line 141, in _new_conn
#     (self.host, self.port), self.timeout, **extra_kw)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/sessions.py", line 618, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/util/connection.py", line 60, in create_connection
#     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/socket.py", line 743, in getaddrinfo
#     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/adapters.py", line 440, in send
#     timeout=timeout
# KeyboardInterrupt
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connectionpool.py", line 601, in urlopen
#     chunked=chunked)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connectionpool.py", line 346, in _make_request
#     self._validate_conn(conn)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connectionpool.py", line 850, in _validate_conn
#     conn.connect()
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connection.py", line 284, in connect
#     conn = self._new_conn()
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connection.py", line 141, in _new_conn
#     (self.host, self.port), self.timeout, **extra_kw)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/util/connection.py", line 60, in create_connection
#     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/socket.py", line 743, in getaddrinfo
#     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
# KeyboardInterrupt
# Process ForkPoolWorker-40:
# Traceback (most recent call last):
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-41-7790e779c516>", line 32, in get_mp_speeches
#     page=page_no))
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/api.py", line 72, in get
#     return request('get', url, params=params, **kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/api.py", line 58, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/sessions.py", line 508, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/sessions.py", line 618, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/adapters.py", line 440, in send
#     timeout=timeout
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connectionpool.py", line 601, in urlopen
#     chunked=chunked)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connectionpool.py", line 346, in _make_request
#     self._validate_conn(conn)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connectionpool.py", line 850, in _validate_conn
#     conn.connect()
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connection.py", line 284, in connect
#     conn = self._new_conn()
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connection.py", line 141, in _new_conn
#     (self.host, self.port), self.timeout, **extra_kw)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/util/connection.py", line 60, in create_connection
#     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/socket.py", line 743, in getaddrinfo
#     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
# KeyboardInterrupt
# Process ForkPoolWorker-36:
# Traceback (most recent call last):
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-41-7790e779c516>", line 32, in get_mp_speeches
#     page=page_no))
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/api.py", line 72, in get
#     return request('get', url, params=params, **kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/api.py", line 58, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/sessions.py", line 508, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/sessions.py", line 618, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/adapters.py", line 440, in send
#     timeout=timeout
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connectionpool.py", line 601, in urlopen
#     chunked=chunked)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connectionpool.py", line 346, in _make_request
#     self._validate_conn(conn)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connectionpool.py", line 850, in _validate_conn
#     conn.connect()
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connection.py", line 284, in connect
#     conn = self._new_conn()
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connection.py", line 141, in _new_conn
#     (self.host, self.port), self.timeout, **extra_kw)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/util/connection.py", line 60, in create_connection
#     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/socket.py", line 743, in getaddrinfo
#     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
# KeyboardInterrupt
# Process ForkPoolWorker-42:
# Traceback (most recent call last):
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-41-7790e779c516>", line 32, in get_mp_speeches
#     page=page_no))
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/api.py", line 72, in get
#     return request('get', url, params=params, **kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/api.py", line 58, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/sessions.py", line 508, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/sessions.py", line 618, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/adapters.py", line 440, in send
#     timeout=timeout
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connectionpool.py", line 601, in urlopen
#     chunked=chunked)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connectionpool.py", line 346, in _make_request
#     self._validate_conn(conn)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connectionpool.py", line 850, in _validate_conn
#     conn.connect()
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connection.py", line 284, in connect
#     conn = self._new_conn()
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connection.py", line 141, in _new_conn
#     (self.host, self.port), self.timeout, **extra_kw)
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/util/connection.py", line 60, in create_connection
#     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#   File "/home/durand/Stuff/Sources/anaconda3/envs/nlp/lib/python3.6/socket.py", line 743, in getaddrinfo
#     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
# KeyboardInterrupt
